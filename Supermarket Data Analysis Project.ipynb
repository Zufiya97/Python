# %%
import pandas as pd
pd.read_csv("sales.csv")
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
import pandas as pd
sale = pd.read_csv("sales.csv")
sale.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating
# 0  Groceries     30         1     30    Cash       2
# 1    Fashion     35         5    175    Card       3
# ...

# %%
sale["Invoice ID"]
# Out:
# 0      460489604
# 1      471006167
# 2      411909258
# 3      487313402
# 4      197763430
#          ...
# 995    818829599
# 996    556589713
# 997     82324424
# 998    783661702
# 999    759171975
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
sale["Category"].unique()
# Out:
# array(['Groceries', 'Fashion', 'Clothing', 'Sporting', 'Books',
#        'Furniture'], dtype=object)

# %%
sale.iloc[786]
# Out:
# Invoice ID     155011528
# Date           1/17/2018
# Time               11:52
# Gender            Female
# Location      Brookfield
# City             NewYork
# Member               Yes
# Category       Groceries
# Price                 22
# Quantity               5
# Total                110
# Payment             Card
# Rating                 5
# Name: 786, dtype: object

# %%
#slicing

# %%
sale[200:225]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 200   576523018  2/15/2018  12:35    Male  Water tower  Chicago     No
# 201   414119922  1/30/2018  11:07    Male  Water tower  Chicago     No
# 202   123247697   2/8/2018  20:03    Male   Brookfield  NewYork     No
# 203    40419058  1/26/2018  14:53    Male  Water tower  Chicago    Yes
# 204   890497298  2/25/2018  18:06  Female  Water tower  Chicago     No
# 205   885702268  1/28/2018  12:45    Male   Brookfield  NewYork     No
# 206   172252194  3/22/2018  20:10  Female    Park lane   Dallas     No
# 207   866140211  2/25/2018  13:34  Female    Park lane   Dallas     No
# 208   597678548  3/15/2018  17:35    Male  Water tower  Chicago    Yes
# 209   428818456  2/25/2018  18:50    Male    Park lane   Dallas    Yes
# 210   236950025   3/9/2018  12:40  Female   Brookfield  NewYork    Yes
# 211    17451639   1/4/2018  14:58    Male  Water tower  Chicago    Yes
# ...

# %%
#filtering data of gender female

# %%
sale[sale["Gender"]=="Female"]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9     562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10    388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 989   941364541  3/13/2018  14:53  Female   Brookfield  NewYork     No
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
#to get starting some values

# %%
sale[sale["Gender"]=="Female"].head(20)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 3    487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4    197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
# 13   942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 14   547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 15   355981315  2/15/2018  15:47  Female   Brookfield  NewYork    Yes
# 16   397754805   2/9/2018  15:59  Female   Brookfield  NewYork    Yes
# 18   542144906   2/6/2018  10:58  Female   Brookfield  NewYork    Yes
# 20   619639105  3/26/2018  19:48  Female   Brookfield  NewYork     No
# 21   443198801  2/24/2018  19:31  Female   Brookfield  NewYork     No
# ...

# %%
#getting access to transaction which is greater than 100

# %%
sale[sale["Total"]>500].head(10)
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 14    547572603  3/21/2018  13:23  Female   Brookfield  NewYork     No
# 36    209725428  3/20/2018  12:45  Female  Water tower  Chicago    Yes
# 40     43371182  1/28/2018  19:24    Male    Park lane   Dallas    Yes
# 46    450817216   2/7/2018  10:57  Female  Water tower  Chicago    Yes
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 52    466598448   2/2/2018  18:50  Female   Brookfield  NewYork     No
# 57    180545139  3/14/2018  10:46  Female   Brookfield  NewYork    Yes
# 70    554361739   1/2/2018  17:24    Male   Brookfield  NewYork    Yes
# 100   515862366  2/12/2018  10:57  Female    Park lane   Dallas     No
# 115   745600525  3/27/2018  13:45    Male    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 14     Fashion     98         7    686    Gpay       3
# 36    Sporting     79         7    553    Gpay       1
# ...

# %%
#using query to find conditional data
#used to add multiple conditional data

# %%
sale.query('Location =="Park lane"')
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 3     487313402  1/22/2018  13:38  Female  Park lane  Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female  Park lane  Dallas     No
# 7     188869875   3/8/2018  13:24    Male  Park lane  Dallas     No
# 8     325637547  1/18/2018  15:33    Male  Park lane  Dallas    Yes
# 9     562942936  2/24/2018  16:05  Female  Park lane  Dallas     No
# ..          ...        ...    ...     ...        ...     ...    ...
# 973    81079897  3/28/2018  12:12  Female  Park lane  Dallas    Yes
# 976   497734676   2/9/2018  14:14    Male  Park lane  Dallas     No
# 977   614557665  3/22/2018  17:16  Female  Park lane  Dallas     No
# 987   245049016  1/20/2018  10:03  Female  Park lane  Dallas     No
# 995   818829599  3/26/2018  11:19    Male  Park lane  Dallas     No
#
#       Category  Price  Quantity  Total Payment  Rating
# 3     Sporting     89         4    356    Gpay       1
# ...

# %%
sale.query("100<Total<200").head(5)
# Out:
#     Invoice ID       Date   Time  Gender     Location     City Member  \
# 1    471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2    411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 7    188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 9    562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
# 10   388412668  2/26/2018  11:32  Female   Brookfield  NewYork     No
#
#      Category  Price  Quantity  Total Payment  Rating
# 1     Fashion     35         5    175    Card       3
# 2    Clothing     57         2    114    Cash       5
# 7       Books     80         2    160    Cash       3
# 9       Books     80         2    160    Cash       4
# 10  Furniture     35         4    140    Gpay       4

# %%
sale.query('Gender=="Female" & City=="Chicago"')
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 13    942406749  1/18/2018  15:20  Female  Water tower  Chicago    Yes
# 36    209725428  3/20/2018  12:45  Female  Water tower  Chicago    Yes
# 42    673603546  3/26/2018  10:11  Female  Water tower  Chicago     No
# 43    328132417   1/3/2018  19:01  Female  Water tower  Chicago     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 965   546718114   1/5/2018  13:41  Female  Water tower  Chicago     No
# 968   934711328  2/17/2018  17:38  Female  Water tower  Chicago     No
# 986   321374195  3/17/2018  14:16  Female  Water tower  Chicago     No
# 988      737210  1/20/2018  20:47  Female  Water tower  Chicago    Yes
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
sale.query('Gender=="Female" | City=="Chicago"')
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 993   455112063  3/19/2018  17:30  Female   Brookfield  NewYork    Yes
# 994   446582560  1/31/2018  19:00    Male  Water tower  Chicago     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 1      Fashion     35         5    175    Card       3
# ...

# %%
sale.query('Gender=="Female" & City=="Chicago"& Total<50')
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 43    328132417   1/3/2018  19:01  Female  Water tower  Chicago     No
# 48    888822600  1/12/2018  19:49  Female  Water tower  Chicago     No
# 64    776761484  1/29/2018  17:59  Female  Water tower  Chicago     No
# 84    616515038  3/10/2018  14:12  Female  Water tower  Chicago    Yes
# 118   456069400   3/9/2018  15:21  Female  Water tower  Chicago     No
# 140   723722504   1/5/2018  20:50  Female  Water tower  Chicago     No
# 156   294501073  3/20/2018  19:50  Female  Water tower  Chicago     No
# 163    58932351   3/1/2018  15:39  Female  Water tower  Chicago    Yes
# 188   458523449  2/25/2018  12:10  Female  Water tower  Chicago    Yes
# 352   232489616  2/27/2018  14:19  Female  Water tower  Chicago     No
# 367   227543927   3/3/2018  18:44  Female  Water tower  Chicago     No
# 398   308591699  3/30/2018  14:26  Female  Water tower  Chicago     No
# ...

# %%
sale.sum()["Total"]
# Out:
# 207788

# %%
sale.sum()["Quantity"]
# Out:
# 4059

# %%
sale.max()
# Out:
# Invoice ID      999665753
# Date             3/9/2018
# Time                20:59
# Gender               Male
# Location      Water tower
# City              NewYork
# Member                Yes
# Category         Sporting
# Price                 100
# Quantity                7
# Total                 693
# Payment              Gpay
# Rating                  5
# dtype: object

# %%
sale[sale["Total"]==sale.max()["Total"]]
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 47    315624039  3/30/2018  19:45  Female  Water tower  Chicago    Yes
# 679   270918350  3/27/2018  13:21  Female    Park lane   Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 47   Groceries     99         7    693    Gpay       3
# 679  Groceries     99         7    693    Gpay       2

# %%
sale["Total"].min()
# Out:
# 1

# %%
sale.min()["Total"]
# Out:
# 1

# %%
sale[sale["Total"]==sale.min()["Total"]]
# Out:
#      Invoice ID       Date   Time  Gender   Location    City Member  \
# 184   801334050  1/21/2018  20:18  Female  Park lane  Dallas     No
# 587   646176653  3/10/2018  19:39    Male  Park lane  Dallas    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 184  Furniture      1         1      1    Gpay       2
# 587   Sporting      1         1      1    Cash       2

# %%
sale.mean()["Total"]
# Out:
# C:\Users\zufiya idrisi\AppData\Local\Temp\ipykernel_13908\3031721490.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sale.mean()["Total"]
# 207.788

# %%
#Group by clause/method

# %%
sale
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
sale.groupby("City").sum()
# Out:
#            Invoice ID  Price  Quantity  Total  Rating
# City
# Chicago  164244758326  16152      1307  65215    1023
# Dallas   160721744770  17289      1344  70432    1003
# NewYork  169526550245  17671      1408  72141     946

# %%
sale["City"].unique()
# Out:
# array(['NewYork', 'Chicago', 'Dallas'], dtype=object)

# %%
sale.groupby("City").sum()["Total"]
# Out:
# City
# Chicago    65215
# Dallas     70432
# NewYork    72141
# Name: Total, dtype: int64

# %%
sale.groupby("Date").sum()["Total"]
# Out:
# Date
# 1/1/2018     2649
# 1/10/2018    1116
# 1/11/2018    1562
# 1/12/2018    2625
# 1/13/2018    2340
#              ...
# 3/5/2018     4616
# 3/6/2018     1915
# 3/7/2018     1048
# 3/8/2018     2638
# 3/9/2018     4300
# Name: Total, Length: 89, dtype: int64

# %%
sale.groupby("Date")

# %%
sale.groupby("Member").sum()["Total"]
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
# 1. Which location has highest and the lowest sales?

# %%
location_list = sale.groupby("Location")

# %%
location = [x for x,y in location_list]

# %%
location
# Out:
# ['Brookfield', 'Park lane', 'Water tower']

# %%
sale.groupby("Location").sum()["Total"]
# Out:
# Location
# Brookfield     72141
# Park lane      70432
# Water tower    65215
# Name: Total, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(location, sale.groupby("Location").sum()["Total"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
 # --> onedork / grade3 / oceans16 / chesterish / monokai / solarized1 --> (themes)
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme("onedork")
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #b5c2d9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #899ab8;
#  background-color: #1d1e23;
#  background: #1d1e23;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d1e23;
#  background: #1d1e23;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #899ab8;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #bbc2e0;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
# 2. Represent the sales on a bar chart, also show the market share for each location using a pie chart

# %%
plt.pie(sale.groupby("Location").sum()["Total"])
# Out:
# ([<matplotlib.patches.Wedge at 0x26eb4799670>,
# ...
#  [Text(0.5080357843151302, 0.9756534435214743, ''),
#   Text(-1.0939745592878725, -0.11497679605427102, ''),
#   Text(0.6072323961649048, -0.917207074246502, '')])

# %%
plt.pie(sale.groupby("Location").sum()["Total"], labels=location)
plt.show()

# %%
sale.groupby(["Location"]).count()
# Out:
#              Invoice ID  Date  Time  Gender  City  Member  Category  Price  \
# Location
# Brookfield          340   340   340     340   340     340       340    340
# Park lane           332   332   332     332   332     332       332    332
# Water tower         328   328   328     328   328     328       328    328
#
#              Quantity  Total  Payment  Rating
# Location
# Brookfield        340    340      340     340
# Park lane         332    332      332     332
# Water tower       328    328      328     328

# %%
sale.groupby(["Location","Gender"]).count()
# Out:
#                     Invoice ID  Date  Time  City  Member  Category  Price  \
# Location    Gender
# Brookfield  Female         179   179   179   179     179       179    179
#             Male           161   161   161   161     161       161    161
# Park lane   Female         179   179   179   179     179       179    179
#             Male           153   153   153   153     153       153    153
# Water tower Female         143   143   143   143     143       143    143
#             Male           185   185   185   185     185       185    185
#
#                     Quantity  Total  Payment  Rating
# Location    Gender
# Brookfield  Female       179    179      179     179
#             Male         161    161      161     161
# Park lane   Female       179    179      179     179
#             Male         153    153      153     153
# Water tower Female       143    143      143     143
#             Male         185    185      185     185

# %%
sale.groupby(["Location","Gender"]).count()["Invoice ID"]
# Out:
# Location     Gender
# Brookfield   Female    179
#              Male      161
# Park lane    Female    179
#              Male      153
# Water tower  Female    143
#              Male      185
# Name: Invoice ID, dtype: int64

# %%
location_sale = sale.groupby(["Location","Gender"]).count()["Invoice ID"]

# %%
location_sale
# Out:
# Location     Gender
# Brookfield   Female    179
#              Male      161
# Park lane    Female    179
#              Male      153
# Water tower  Female    143
#              Male      185
# Name: Invoice ID, dtype: int64

# %%
#unstack methhod --> (Used for multiple indexes)

# %%
unstack_sale = location_sale.unstack(level=0)

# %%
unstack_sale
# Out:
# Location  Brookfield  Park lane  Water tower
# Gender
# Female           179        179          143
# Male             161        153          185

# %%
unstack_sale.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
members = sale.groupby(["Member","Location"]).count()["Invoice ID"]

# %%
members
# Out:
# Member  Location
# No      Brookfield     173
#         Park lane      167
#         Water tower    159
# Yes     Brookfield     167
#         Park lane      165
#         Water tower    169
# Name: Invoice ID, dtype: int64

# %%
members.unstack(level=0).plot(kind="bar")
plt.show()

# %%
rating = sale.groupby("Location").mean()["Rating"]

# %%
rating
# Out:
# Location
# Brookfield     2.782353
# Park lane      3.021084
# Water tower    3.118902
# Name: Rating, dtype: float64

# %%
rating.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Location'>

# %%
# Which city has more females shopping?
#gender

# %%
sale.groupby(["Gender","City"]).count()["Invoice ID"]
# Out:
# Gender  City
# Female  Chicago    143
#         Dallas     179
#         NewYork    179
# Male    Chicago    185
#         Dallas     153
#         NewYork    161
# Name: Invoice ID, dtype: int64

# %%
female_shopper = sale.groupby(["Gender","City"]).count()["Invoice ID"]

# %%
female_shopper.unstack(level=0).plot(kind="bar")
plt.show()

# %%
#Who spends more? Men or Women?

# %%
spend = sale.groupby("Gender").sum()["Total"]

# %%
spend.plot(kind="bar")
plt.show()

# %%
# Which type of customer spends more? Member or a non member?

# %%
mem_spend = sale.groupby("Member").sum()["Total"]

# %%
mem_spend
# Out:
# Member
# No     100245
# Yes    107543
# Name: Total, dtype: int64

# %%
mem_spend.plot(kind="bar")
plt.show()

# %%
#Which product line spends more?

# %%
cat_sale = sale.groupby("Category").count()["Rating"]

# %%
cat_sale.plot(kind="bar")
plt.show()

# %%
# Which product line is popular among men vs women?

# %%
prod_line = sale.groupby(["Gender","Category"]).sum()["Rating"]

# %%
prod_line.unstack(level=0).plot(kind="bar")
plt.show()

# %%
# What days of the month make most sales?

# %%
sale["Date"]
# Out:
# 0      1/25/2018
# 1      3/19/2018
# 2      2/25/2018
# 3      1/22/2018
# 4      2/18/2018
#          ...
# 995    3/26/2018
# 996    2/20/2018
# 997     2/6/2018
# 998    1/29/2018
# 999    1/31/2018
# Name: Date, Length: 1000, dtype: object

# %%
pd.to_datetime(sale["Date"])
# Out:
# 0     2018-01-25
# 1     2018-03-19
# 2     2018-02-25
# 3     2018-01-22
# 4     2018-02-18
#          ...
# 995   2018-03-26
# 996   2018-02-20
# 997   2018-02-06
# 998   2018-01-29
# 999   2018-01-31
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
pd.to_datetime(sale["Date"]).dt.day
# Out:
# 0      25
# 1      19
# 2      25
# 3      22
# 4      18
#        ..
# 995    26
# 996    20
# 997     6
# 998    29
# 999    31
# Name: Date, Length: 1000, dtype: int64

# %%
pd.to_datetime(sale["Date"]).dt.month
# Out:
# 0      1
# 1      3
# 2      2
# 3      1
# 4      2
#       ..
# 995    3
# 996    2
# 997    2
# 998    1
# 999    1
# Name: Date, Length: 1000, dtype: int64

# %%
pd.to_datetime(sale["Date"]).dt.year
# Out:
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
#        ...
# 995    2018
# 996    2018
# 997    2018
# 998    2018
# 999    2018
# Name: Date, Length: 1000, dtype: int64

# %%
sale["Day"] = pd.to_datetime(sale["Date"]).dt.day
sale.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day
# 0  Groceries     30         1     30    Cash       2   25
# 1    Fashion     35         5    175    Card       3   19
# ...

# %%
day_sale = sale.groupby("Day").sum()["Total"]

# %%
day_sale.plot()
plt.show()

# %%
# Which months make the most sales?

# %%
sale["Month"] = pd.to_datetime(sale["Date"]).dt.month

# %%
sale.head(10)
# Out:
#    Invoice ID       Date   Time  Gender     Location     City Member  \
# 0   460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1   471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2   411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3   487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4   197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5   263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6    99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# 7   188869875   3/8/2018  13:24    Male    Park lane   Dallas     No
# 8   325637547  1/18/2018  15:33    Male    Park lane   Dallas    Yes
# 9   562942936  2/24/2018  16:05  Female    Park lane   Dallas     No
#
#     Category  Price  Quantity  Total Payment  Rating  Day  Month
# 0  Groceries     30         1     30    Cash       2   25      1
# 1    Fashion     35         5    175    Card       3   19      3
# ...

# %% [markdown]
# month_sale = sale.groupby("Month").sum()["Total"]

# %%
month_sale.plot(kind="bar")
plt.grid()
plt.show()

# %%
# Which hours make the most sales?

# %%
sale["Time"]
# Out:
# 0      16:46
# 1      16:48
# 2      13:33
# 3      13:38
# 4      15:31
#        ...
# 995    11:19
# 996    17:17
# 997    11:44
# 998    15:44
# 999    10:13
# Name: Time, Length: 1000, dtype: object

# %%
sale["Hour"] = pd.to_datetime(sale["Time"]).dt.hour
sale
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating  Day  Month  Hour
# ...

# %%
hour_sale = sale.groupby("Hour").sum()["Total"]

# %%
hour_sale.plot(grid=True)
plt.show()

# %%
# What time do people make more epayments 
# vs
# what time people make more cash payments ??

# %%
sale.groupby(["Payment", "Hour"]).count()["Invoice ID"].unstack(level=0).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Hour'>
